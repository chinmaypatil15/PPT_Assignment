# %%
from math import ceil

class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next
class Solution:
    def deleteMiddle(self, head):
        if not head or not head.next:
            return None
        mapped = []
        n = 0
        while head:
            mapped.append(head)
            n += 1
            head = head.next
        middle = n // 2 if n % 2 else ceil(n / 2)
        if n - 1:
            mapped[middle - 1].next = mapped[middle].next
            return mapped[0]
        else:
            return None

# Example 1
head1 = ListNode(1)
node2 = ListNode(2)
node3 = ListNode(3)
node4 = ListNode(4)
node5 = ListNode(5)

head1.next = node2
node2.next = node3
node3.next = node4
node4.next = node5

solution = Solution()

result1 = solution.deleteMiddle(head1)

# Example 2
head2 = ListNode(2)
node4 = ListNode(4)
node6 = ListNode(6)
node7 = ListNode(7)
node5 = ListNode(5)
node1 = ListNode(1)

head2.next = node4
node4.next = node6
node6.next = node7
node7.next = node5
node5.next = node1

result2 = solution.deleteMiddle(head2)

def printLinkedList(head):
    current = head
    while current:
        print(current.val, end=' ')
        current = current.next
    print()

printLinkedList(result1)
printLinkedList(result2)
# Out:
# 1 2 4 5
# 2 4 6 5 1

# %%
class Solution:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

def LinkLoop(head):
    slow = head
    fast = head

    while fast and fast.next:
        slow = slow.next
        fast = fast.next.next

        if slow == fast:
            return True

    return False
# Example 1
head1 = Solution(1)
node2 = Solution(3)
node3 = Solution(4)

head1.next = node2
node2.next = node3
node3.next = node2

result1 = LinkLoop(head1)
print(result1)

# Example 2
head2 = Solution(1)
node2 = Solution(8)
node3 = Solution(3)
node4 = Solution(4)

head2.next = node2
node2.next = node3
node3.next = node4

result2 = LinkLoop(head2)
print(result2)
# Out:
# True
# False

# %%
class Solution:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next
def nthfromend(head, N):
    if not head:
        return -1
    slow = head
    fast = head
    for _ in range(N):
        if fast:
            fast = fast.next
        else:
            return -1
    while fast:
        slow = slow.next
        fast = fast.next

    if slow:
        return slow.val
    else:
        return -1

# Example 1
head1 = Solution(1)
node2 = Solution(2)
node3 = Solution(3)
node4 = Solution(4)
node5 = Solution(5)
node6 = Solution(6)
node7 = Solution(7)
node8 = Solution(8)
node9 = Solution(9)

head1.next = node2
node2.next = node3
node3.next = node4
node4.next = node5
node5.next = node6
node6.next = node7
node7.next = node8
node8.next = node9

N1 = 2
result1 = nthfromend(head1, N1)
print(result1)

# Example 2
head2 = ListNode(10)
node2 = ListNode(5)
node3 = ListNode(100)
node4 = ListNode(5)

head2.next = node2
node2.next = node3
node3.next = node4

N2 = 5
result2 = nthfromend(head2, N2)
print(result2)
# Out:
# 8
# -1

# %%
class Solution:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

def Palindrome(head):
    values = []
    current = head
    while current:
        values.append(current.val)
        current = current.next
    left = 0
    right = len(values) - 1
    while left < right:
        if values[left] != values[right]:
            return False
        left += 1
        right -= 1
    return True
# Example 1
head1 = Solution('R')
node2 = Solution('A')
node3 = Solution('D')
node4 = Solution('A')
node5 = Solution('R')

head1.next = node2
node2.next = node3
node3.next = node4
node4.next = node5

result1 = Palindrome(head1)
print(result1)

# Example 2
head2 = Solution('C')
node2 = Solution('O')
node3 = Solution('D')
node4 = Solution('E')

head2.next = node2
node2.next = node3
node3.next = node4

result2 = Palindrome(head2)
print(result2)
# Out:
# True
# False

# %%
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

def detectAndRemoveLoop(head):
    slow = head
    fast = head
    while fast and fast.next:
        slow = slow.next
        fast = fast.next.next
        if slow == fast:
            break
    if fast is None or fast.next is None:
        return head
    slow = head

    while slow != fast:
        slow = slow.next
        fast = fast.next

    # Step 3: Remove the loop
    while fast.next != slow:
        fast = fast.next

    fast.next = None

    return head


# Example 1
head1 = ListNode(1)
node2 = ListNode(3)
node3 = ListNode(4)

head1.next = node2
node2.next = node3
node3.next = node2

result1 = detectAndRemoveLoop(head1)
print(result1.val)

# Example 2
head2 = ListNode(1)
node2 = ListNode(8)
node3 = ListNode(3)
node4 = ListNode(4)

head2.next = node2
node2.next = node3
node3.next = node4

result2 = detectAndRemoveLoop(head2)
print(result2.val)

# Example 3
head3 = ListNode(1)
node2 = ListNode(2)
node3 = ListNode(3)
node4 = ListNode(4)

head3.next = node2
node2.next = node3
node3.next = node4
node4.next = node2

result3 = detectAndRemoveLoop(head3)
print(result3.val)
# Out:
# 1
# 1
# 1

# %%
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

def deleteNodes(head, M, N):
    if not head:
        return None
    dummy = ListNode(0)
    dummy.next = head
    curr = dummy
    while curr:
        for _ in range(M):
            if curr:
                curr = curr.next
            else:
                return dummy.next
        for _ in range(N):
            if curr and curr.next:
                curr.next = curr.next.next
            else:
                return dummy.next
    return dummy.next

# Example 1
head1 = ListNode(1)
node2 = ListNode(2)
node3 = ListNode(3)
node4 = ListNode(4)
node5 = ListNode(5)
node6 = ListNode(6)
node7 = ListNode(7)
node8 = ListNode(8)

head1.next = node2
node2.next = node3
node3.next = node4
node4.next = node5
node5.next = node6
node6.next = node7
node7.next = node8

M1 = 2
N1 = 2

result1 = deleteNodes(head1, M1, N1)

while result1:
    print(result1.val, end=" ")
    result1 = result1.next


# Example 2
head2 = ListNode(1)
node2 = ListNode(2)
node3 = ListNode(3)
node4 = ListNode(4)
node5 = ListNode(5)
node6 = ListNode(6)
node7 = ListNode(7)
node8 = ListNode(8)
node9 = ListNode(9)
node10 = ListNode(10)

head2.next = node2
node2.next = node3
node3.next = node4
node4.next = node5
node5.next = node6
node6.next = node7
node7.next = node8
node8.next = node9
node9.next = node10

M2 = 3
N2 = 2

result2 = deleteNodes(head2, M2, N2)

while result2:
    print(result2.val, end=" ")
    result2 = result2.next

# Example 3
head3 = ListNode(1)
node2 = ListNode(2)
node3 = ListNode(3)
node4 = ListNode(4)
node5 = ListNode(5)
node6 = ListNode(6)
node7 = ListNode(7)
node8 = ListNode(8)
node9 = ListNode(9)
node10 = ListNode(10)

head3.next = node2
node2.next = node3
node3.next = node4
node4.next = node5
node5.next = node6
node6.next = node7
node7.next = node8
node8.next = node9
node9.next = node10

M3 = 1
N3 = 1

result3 = deleteNodes(head3, M3, N3)

while result3:
    print(result3.val, end=" ")
    result3 = result3.next
# Out:
# 1 2 5 6 1 2 3 6 7 8 1 3 5 7 9

# %%
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

def mergeLists(first: ListNode, second: ListNode) -> ListNode:
    if not second:
        return first
    firstPtr = first
    secondPtr = second
    while firstPtr and secondPtr:
        firstNext = firstPtr.next
        secondNext = secondPtr.next

        secondPtr.next = firstNext
        firstPtr.next = secondPtr

        firstPtr = firstNext
        secondPtr = secondNext
    if secondPtr:
        firstPtr.next = secondPtr

    return first

# Example
firstHead = ListNode(5)
firstNode2 = ListNode(7)
firstNode3 = ListNode(17)
firstNode4 = ListNode(13)
firstNode5 = ListNode(11)

firstHead.next = firstNode2
firstNode2.next = firstNode3
firstNode3.next = firstNode4
firstNode4.next = firstNode5

secondHead = ListNode(12)
secondNode2 = ListNode(10)
secondNode3 = ListNode(2)
secondNode4 = ListNode(4)
secondNode5 = ListNode(6)

secondHead.next = secondNode2
secondNode2.next = secondNode3
secondNode3.next = secondNode4
secondNode4.next = secondNode5

result = mergeLists(firstHead, secondHead)

while result:
    print(result.val, end=" ")
    result = result.next
# Out:
# 5 12 7 10 17 2 13 4 11 6

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    def add_to_front(self, data):
        new_node = Node(data)
        new_node.next = self.head
        self.head = new_node

    def is_circular(self):
        if self.head is None:
            return False
        slow = self.head
        fast = self.head.next
        while fast is not None and fast.next is not None:
            if slow == fast:
                return True
            slow = slow.next
            fast = fast.next.next
        return False

list = LinkedList()
list.add_to_front(1)
list.add_to_front(2)
list.add_to_front(3)
list.add_to_front(4)
print(list.is_circular())
# Out:
# False
